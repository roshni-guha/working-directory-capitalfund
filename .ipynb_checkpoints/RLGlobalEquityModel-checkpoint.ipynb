# %% [markdown]
# # Reinforcement Learning for Global Equity ETF Allocation
#
# This notebook implements a PPO-based RL agent that dynamically allocates across global equity ETFs using macro signals.
#
# **Key Features:**
# - State: Momentum features from TLT, GLD, USO, SLV, VIXY, IBIT
# - Actions: Allocate to SPY, EWJ, INDA, MCHI, EZU, or BIL (cash)
# - Reward: Risk-adjusted returns (Sharpe-like)
# - Algorithm: Proximal Policy Optimization (PPO)

# %%
import pandas as pd
import datetime as dt
import polars as pl
import numpy as np
import matplotlib.pyplot as plt
from typing import Callable, Dict
from trading_engine.core import (
    read_data, create_model_state, orchestrate_model_backtests,
    orchestrate_model_simulations, orchestrate_portfolio_backtests,
    orchestrate_portfolio_simulations
)
from trading_engine.models import MODELS
from trading_engine.optimizers import OPTIMIZERS
from common.constants import ProcessingMode

# RL imports
import torch
import torch.nn as nn
import torch.optim as optim
from torch.distributions import Categorical

# %% [markdown]
# ## 1. PPO Policy Network

# %%
class PolicyNetwork(nn.Module):
    """Neural network that maps state features to action probabilities."""
    
    def __init__(self, state_dim: int, action_dim: int, hidden_dim: int = 128):
        super(PolicyNetwork, self).__init__()
        self.fc1 = nn.Linear(state_dim, hidden_dim)
        self.fc2 = nn.Linear(hidden_dim, hidden_dim)
        self.fc3 = nn.Linear(hidden_dim, action_dim)
        self.relu = nn.ReLU()
        self.softmax = nn.Softmax(dim=-1)
        
    def forward(self, state):
        x = self.relu(self.fc1(state))
        x = self.relu(self.fc2(x))
        action_probs = self.softmax(self.fc3(x))
        return action_probs


class ValueNetwork(nn.Module):
    """Neural network that estimates state values for advantage calculation."""
    
    def __init__(self, state_dim: int, hidden_dim: int = 128):
        super(ValueNetwork, self).__init__()
        self.fc1 = nn.Linear(state_dim, hidden_dim)
        self.fc2 = nn.Linear(hidden_dim, hidden_dim)
        self.fc3 = nn.Linear(hidden_dim, 1)
        self.relu = nn.ReLU()
        
    def forward(self, state):
        x = self.relu(self.fc1(state))
        x = self.relu(self.fc2(x))
        value = self.fc3(x)
        return value

# %% [markdown]
# ## 2. PPO Agent

# %%
class PPOAgent:
    """Proximal Policy Optimization agent for ETF allocation."""
    
    def __init__(self, state_dim: int, action_dim: int, 
                 lr_policy: float = 3e-4, lr_value: float = 1e-3,
                 gamma: float = 0.95, epsilon_clip: float = 0.2,
                 hidden_dim: int = 128):
        self.gamma = gamma
        self.epsilon_clip = epsilon_clip
        self.action_dim = action_dim
        
        # Networks
        self.policy = PolicyNetwork(state_dim, action_dim, hidden_dim)
        self.value = ValueNetwork(state_dim, hidden_dim)
        
        # Optimizers
        self.policy_optimizer = optim.Adam(self.policy.parameters(), lr=lr_policy)
        self.value_optimizer = optim.Adam(self.value.parameters(), lr=lr_value)
        
        # Storage for trajectories
        self.states = []
        self.actions = []
        self.rewards = []
        self.action_probs = []
        self.is_terminals = []
        
    def select_action(self, state, training=True):
        """Select action based on current policy."""
        state_tensor = torch.FloatTensor(state).unsqueeze(0)
        action_probs = self.policy(state_tensor)
        
        if training:
            # Sample from distribution during training (exploration)
            dist = Categorical(action_probs)
            action = dist.sample()
        else:
            # Choose best action during inference (exploitation)
            action = torch.argmax(action_probs, dim=1)
        
        return action.item(), action_probs[0, action.item()].item()
    
    def store_transition(self, state, action, reward, action_prob, is_terminal):
        """Store experience tuple."""
        self.states.append(state)
        self.actions.append(action)
        self.rewards.append(reward)
        self.action_probs.append(action_prob)
        self.is_terminals.append(is_terminal)
    
    def compute_advantages(self):
        """Compute GAE (Generalized Advantage Estimation)."""
        states_tensor = torch.FloatTensor(np.array(self.states))
        values = self.value(states_tensor).detach().numpy().flatten()
        
        advantages = []
        returns = []
        
        # Compute discounted returns and advantages
        gae = 0
        next_value = 0
        
        for t in reversed(range(len(self.rewards))):
            if self.is_terminals[t]:
                next_value = 0
                gae = 0
            
            # TD error: δ = r + γV(s') - V(s)
            delta = self.rewards[t] + self.gamma * next_value - values[t]
            # GAE: A = δ + γλδ' + ...
            gae = delta + self.gamma * 0.95 * gae  # λ=0.95
            
            advantages.insert(0, gae)
            returns.insert(0, gae + values[t])
            next_value = values[t]
        
        # Normalize advantages
        advantages = np.array(advantages)
        advantages = (advantages - advantages.mean()) / (advantages.std() + 1e-8)
        
        return advantages, np.array(returns)
    
    def update(self, epochs=10, batch_size=64):
        """Update policy and value networks using PPO."""
        if len(self.states) == 0:
            return
        
        # Compute advantages
        advantages, returns = self.compute_advantages()
        
        # Convert to tensors
        states_tensor = torch.FloatTensor(np.array(self.states))
        actions_tensor = torch.LongTensor(np.array(self.actions))
        old_probs_tensor = torch.FloatTensor(np.array(self.action_probs))
        advantages_tensor = torch.FloatTensor(advantages)
        returns_tensor = torch.FloatTensor(returns)
        
        # PPO update for multiple epochs
        for _ in range(epochs):
            # Mini-batch update
            indices = np.arange(len(self.states))
            np.random.shuffle(indices)
            
            for start in range(0, len(self.states), batch_size):
                end = min(start + batch_size, len(self.states))
                batch_indices = indices[start:end]
                
                # Get batch
                batch_states = states_tensor[batch_indices]
                batch_actions = actions_tensor[batch_indices]
                batch_old_probs = old_probs_tensor[batch_indices]
                batch_advantages = advantages_tensor[batch_indices]
                batch_returns = returns_tensor[batch_indices]
                
                # Evaluate current policy
                action_probs = self.policy(batch_states)
                dist = Categorical(action_probs)
                new_probs = dist.log_prob(batch_actions).exp()
                
                # Ratio for PPO
                ratio = new_probs / (batch_old_probs + 1e-8)
                
                # PPO clipped objective
                surr1 = ratio * batch_advantages
                surr2 = torch.clamp(ratio, 1 - self.epsilon_clip, 1 + self.epsilon_clip) * batch_advantages
                policy_loss = -torch.min(surr1, surr2).mean()
                
                # Value loss
                value_pred = self.value(batch_states).squeeze()
                value_loss = nn.MSELoss()(value_pred, batch_returns)
                
                # Update policy
                self.policy_optimizer.zero_grad()
                policy_loss.backward()
                torch.nn.utils.clip_grad_norm_(self.policy.parameters(), 0.5)
                self.policy_optimizer.step()
                
                # Update value
                self.value_optimizer.zero_grad()
                value_loss.backward()
                torch.nn.utils.clip_grad_norm_(self.value.parameters(), 0.5)
                self.value_optimizer.step()
        
        # Clear trajectories
        self.clear_memory()
    
    def clear_memory(self):
        """Clear stored trajectories."""
        self.states = []
        self.actions = []
        self.rewards = []
        self.action_probs = []
        self.is_terminals = []

# %% [markdown]
# ## 3. RL Model Class for Trading Engine Integration
#
# This class follows the same pattern as other models in trading_model0, making it easy to use with orchestrators.

# %%
class RLGlobalEquityAllocator:
    """
    RL-based allocator for global equity ETFs.

    This class wraps the PPO agent and provides a clean interface for trading_model0.

    Usage:
        # Initialize
        allocator = RLGlobalEquityAllocator(
            trade_tickers=['SPY-US', 'EWJ-US', 'INDA-US', 'MCHI-US', 'EZU-US', 'BIL-US'],
            signal_tickers=['TLT-US', 'GLD-US', 'USO-US', 'SLV-US', 'VIXY-US', 'IBIT-US'],
            momentum_columns=['close_momentum_10', 'close_momentum_20', 'close_momentum_60']
        )

        # Train
        allocator.train(model_state, prices, num_episodes=50)

        # Save/Load
        allocator.save('rl_global_equity_model')
        allocator = RLGlobalEquityAllocator.load('rl_global_equity_model')

        # Use in models_registry
        models_registry = {
            "RL_GLOBAL_EQUITY": {
                "tickers": trade_tickers + signal_tickers,
                "columns": momentum_columns,
                "function": allocator,
            }
        }
    """

    def __init__(
        self,
        trade_tickers: list,
        signal_tickers: list,
        momentum_columns: list,
        volatility_penalty: float = 0.5,
        lr_policy: float = 3e-4,
        lr_value: float = 1e-3,
        hidden_dim: int = 128,
        trained_agent: PPOAgent = None
    ):
        """
        Initialize the RL allocator.

        Args:
            trade_tickers: List of ETFs to allocate between
            signal_tickers: List of ETFs used as state signals
            momentum_columns: Momentum features to use
            volatility_penalty: Penalty for volatility in reward function
            lr_policy: Learning rate for policy network
            lr_value: Learning rate for value network
            hidden_dim: Hidden dimension for neural networks
            trained_agent: Pre-trained PPO agent (optional)
        """
        self.trade_tickers = trade_tickers
        self.signal_tickers = signal_tickers
        self.momentum_columns = momentum_columns
        self.volatility_penalty = volatility_penalty
        self.lr_policy = lr_policy
        self.lr_value = lr_value
        self.hidden_dim = hidden_dim

        self.state_dim = len(signal_tickers) * len(momentum_columns)
        self.action_dim = len(trade_tickers)

        self.agent = trained_agent
        self.is_trained = trained_agent is not None

    def train(
        self,
        model_state: pl.LazyFrame,
        prices: pl.LazyFrame,
        num_episodes: int = 100,
        update_frequency: int = 2000,
        volatility_window: int = 20,
        verbose: bool = True
    ):
        """
        Train the PPO agent on historical data.

        Args:
            model_state: LazyFrame with features
            prices: LazyFrame with price data
            num_episodes: Number of training episodes
            update_frequency: Update agent every N timesteps
            volatility_window: Window for volatility calculation
            verbose: Print progress
        """
        if verbose:
            print("="*80)
            print("TRAINING RL GLOBAL EQUITY ALLOCATOR")
            print("="*80)

        # Initialize agent if not already initialized
        if self.agent is None:
            self.agent = PPOAgent(
                self.state_dim,
                self.action_dim,
                lr_policy=self.lr_policy,
                lr_value=self.lr_value,
                hidden_dim=self.hidden_dim
            )

        if hasattr(model_state, "collect"):            # LazyFrame
            df = model_state.collect()
        else:                                          # Polars DataFrame
            df = model_state.clone()
        
        if hasattr(prices, "collect"):                 # LazyFrame
            prices_df = prices.collect()
        else:
            prices_df = prices.clone()
        
        # Fix dates for both pandas and polars
        if isinstance(df, pl.DataFrame):
            dates = df.select('date').unique().sort('date')['date'].to_list()
        else:  # pandas
            dates = df["date"].drop_duplicates().sort_values().tolist()

        if verbose:
            print(f"\nTraining Configuration:")
            print(f"  • Training days: {len(dates)}")
            print(f"  • State dimension: {self.state_dim}")
            print(f"  • Action dimension: {self.action_dim}")
            print(f"  • Episodes: {num_episodes}")
            print(f"  • Volatility penalty: {self.volatility_penalty}")

        # Training loop
        episode_rewards = []

        for episode in range(num_episodes):
            total_reward = 0
            timestep = 0
            recent_returns = []

            for i in range(len(dates) - 1):
                date = dates[i]
                next_date = dates[i + 1]

                # Extract state features
                state_features = []
                date_df = df.filter(pl.col('date') == date)

                for signal_ticker in self.signal_tickers:
                    ticker_df = date_df.filter(pl.col('ticker') == signal_ticker)
                    for momentum_col in self.momentum_columns:
                        if len(ticker_df) > 0 and momentum_col in ticker_df.columns:
                            val = ticker_df.select(momentum_col).to_numpy()[0, 0]
                            state_features.append(val if not np.isnan(val) else 0.0)
                        else:
                            state_features.append(0.0)

                state = np.array(state_features, dtype=np.float32)

                # Select action
                action_idx, action_prob = self.agent.select_action(state, training=True)
                selected_ticker = self.trade_tickers[action_idx]

                # Get return for selected asset
                row_today = prices_df.filter(pl.col("date") == date)
                row_next = prices_df.filter(pl.col("date") == next_date)
                
                if len(row_today) > 0 and len(row_next) > 0:
                    current_price = row_today.select(selected_ticker).item()
                    next_price = row_next.select(selected_ticker).item()
                    daily_return = (next_price - current_price) / current_price
                else:
                    daily_return = 0.0

                recent_returns.append(daily_return)
                if len(recent_returns) > volatility_window:
                    recent_returns.pop(0)

                # Compute reward: return - λ * volatility
                if len(recent_returns) >= 2:
                    volatility = np.std(recent_returns)
                    reward = daily_return - self.volatility_penalty * volatility
                else:
                    reward = daily_return

                # Store transition
                is_terminal = (i == len(dates) - 2)
                self.agent.store_transition(state, action_idx, reward, action_prob, is_terminal)

                total_reward += daily_return
                timestep += 1

                # Update agent periodically
                if timestep % update_frequency == 0:
                    self.agent.update()

            # Final update at end of episode
            self.agent.update()

            episode_rewards.append(total_reward)

            if verbose and (episode + 1) % 10 == 0:
                avg_reward = np.mean(episode_rewards[-10:])
                print(f"Episode {episode + 1}/{num_episodes}, Avg Return (last 10): {avg_reward:.4f}")

        self.is_trained = True

        if verbose:
            print("\n✓ Training complete!")
            print("="*80)

            # Plot training progress
            plt.figure(figsize=(10, 5))
            plt.plot(episode_rewards)
            plt.title('Training Progress: Episode Returns')
            plt.xlabel('Episode')
            plt.ylabel('Total Return')
            plt.grid(True, alpha=0.3)
            plt.tight_layout()
            plt.show()

    def save(self, path: str):
        """Save trained model and configuration."""
        if not self.is_trained:
            raise ValueError("Model must be trained before saving")

        torch.save({
            'policy_state_dict': self.agent.policy.state_dict(),
            'value_state_dict': self.agent.value.state_dict(),
            'trade_tickers': self.trade_tickers,
            'signal_tickers': self.signal_tickers,
            'momentum_columns': self.momentum_columns,
            'volatility_penalty': self.volatility_penalty,
            'lr_policy': self.lr_policy,
            'lr_value': self.lr_value,
            'hidden_dim': self.hidden_dim,
            'state_dim': self.state_dim,
            'action_dim': self.action_dim,
        }, f'{path}.pth')

        print(f"✓ Model saved to {path}.pth")

    @classmethod
    def load(cls, path: str) -> 'RLGlobalEquityAllocator':
        """Load trained model and configuration."""
        checkpoint = torch.load(f'{path}.pth')

        # Create instance
        allocator = cls(
            trade_tickers=checkpoint['trade_tickers'],
            signal_tickers=checkpoint['signal_tickers'],
            momentum_columns=checkpoint['momentum_columns'],
            volatility_penalty=checkpoint['volatility_penalty'],
            lr_policy=checkpoint['lr_policy'],
            lr_value=checkpoint['lr_value'],
            hidden_dim=checkpoint['hidden_dim']
        )

        # Initialize and load agent
        allocator.agent = PPOAgent(
            checkpoint['state_dim'],
            checkpoint['action_dim'],
            lr_policy=checkpoint['lr_policy'],
            lr_value=checkpoint['lr_value'],
            hidden_dim=checkpoint['hidden_dim']
        )
        allocator.agent.policy.load_state_dict(checkpoint['policy_state_dict'])
        allocator.agent.value.load_state_dict(checkpoint['value_state_dict'])
        allocator.is_trained = True

        print(f"✓ Model loaded from {path}.pth")
        return allocator

    def __call__(self, lf: pl.LazyFrame) -> pl.LazyFrame:
        """
        Generate trading weights from model_state.

        This is the main interface for trading_model0 orchestrators.

        Args:
            lf: LazyFrame with columns [date, ticker, momentum features...]

        Returns:
            LazyFrame with columns [date, SPY-US, EWJ-US, ...] containing weights
        """
        if not self.is_trained:
            raise ValueError("Model must be trained before generating signals")

        # Collect data
        df = lf.collect()

        # Get unique dates
        dates = df.select('date').unique().sort('date')

        # Initialize weights storage
        weights_list = []

        for date_row in dates.iter_rows():
            date = date_row[0]

            # Extract state: momentum features from signal tickers
            state_features = []
            date_df = df.filter(pl.col('date') == date)

            for signal_ticker in self.signal_tickers:
                ticker_df = date_df.filter(pl.col('ticker') == signal_ticker)

                for momentum_col in self.momentum_columns:
                    if len(ticker_df) > 0 and momentum_col in ticker_df.columns:
                        val = ticker_df.select(momentum_col).to_numpy()[0, 0]
                        state_features.append(val if not np.isnan(val) else 0.0)
                    else:
                        state_features.append(0.0)

            # Convert to numpy array
            state = np.array(state_features, dtype=np.float32)

            # Get action from agent
            action_idx, _ = self.agent.select_action(state, training=False)

            # Create one-hot allocation
            weight_dict = {'date': date}
            for i, ticker in enumerate(self.trade_tickers):
                weight_dict[ticker] = 1.0 if i == action_idx else 0.0

            weights_list.append(weight_dict)

        # Convert to polars DataFrame
        weights_df = pl.DataFrame(weights_list)

        return weights_df.lazy()

print("✓ RLGlobalEquityAllocator class defined!")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[103], line 1
# ----> 1 class RLGlobalEquityAllocator:
#       2     """
#       3     RL-based allocator for global equity ETFs.
#       4     """
#       6     def __init__(
#       7         self,
#       8         trade_tickers: list,
#    (...)     15         trained_agent: PPOAgent = None,
#      16     ):
#
# Cell In[103], line 33, in RLGlobalEquityAllocator()
#      28     self.agent = trained_agent
#      29     self.is_trained = trained_agent is not None
#      31 def train(
#      32     self,
# ---> 33     model_state: Union[pl.LazyFrame, pl.DataFrame],
#      34     prices: Union[pl.LazyFrame, pl.DataFrame],
#      35     num_episodes: int = 100,
#      36     update_frequency: int = 2000,
#      37     volatility_window: int = 20,
#      38     verbose: bool = True,
#      39 ):
#      40     """
#      41     Train the PPO agent on historical data.
#      42
#    (...)     45         prices: LazyFrame/DataFrame with prices (wide format: date, SPY-US, EWJ-US, ...)
#      46     """
#      48     if verbose:
#
# NameError: name 'Union' is not defined

# %% [markdown]
# ## 4. Example Usage with trading_model0
#
# Now let's see how to use the RL allocator with the trading_engine orchestrators.

# %%
# The RLGlobalEquityAllocator class handles all training internally
# No need for a separate train_rl_agent function anymore!

print("Note: Training is now handled by the RLGlobalEquityAllocator.train() method")
print("See the class definition above for implementation details.")
# Out:
# Note: Training is now handled by the RLGlobalEquityAllocator.train() method
# See the class definition above for implementation details.

# %% [markdown]
# ## 5. Configuration and Data Loading

# %%
# Experiment config
universe = [
    "SPY-US", "SLV-US", "GLD-US", "TLT-US", "USO-US", "UNG-US", "IXJ-US",
    "KXI-US", "JXI-US", "IXG-US", "IXN-US", "RXI-US", "MXI-US", "EXI-US",
    "IXC-US", "IEI-US", "SHY-US", "BIL-US", "JPXN-US", "INDA-US", "MCHI-US",
    "EZU-US", "IBIT-US", "ETHA-US", "VIXY-US", "EWJ-US"
]

# Trade tickers (actions)
trade_tickers = ["SPY-US", "EWJ-US", "INDA-US", "MCHI-US", "EZU-US", "BIL-US"]

# Signal tickers (state)
signal_tickers = ["TLT-US", "GLD-US", "USO-US", "SLV-US", "VIXY-US", "IBIT-US"]

# Features
momentum_columns = ["close_momentum_10", "close_momentum_20", "close_momentum_60"]

initial_value = 1_000_000
start_date = dt.date(2004, 1, 2)
end_date = dt.date(2025, 9, 10)

# %%
# Load data and create model state
lf = read_data()
model_state, prices = create_model_state(
    lf=lf,
    features=momentum_columns,
    start_date=start_date,
    end_date=end_date,
    universe=universe
)

print("Data loaded successfully!")
# Out:
# Data loaded successfully!

# %% [markdown]
# ## 6. Train the RL Agent

# %%
# Initialize and train the allocator
allocator = RLGlobalEquityAllocator(
    trade_tickers=trade_tickers,
    signal_tickers=signal_tickers,
    momentum_columns=momentum_columns,
    volatility_penalty=0.5,
    lr_policy=3e-4,
    lr_value=1e-3,
    hidden_dim=128
)

# Train the agent
allocator.train(
    model_state=model_state,
    prices=prices,
    num_episodes=50,  # Adjust based on your needs
    update_frequency=2000,
    verbose=True
)

# Save trained model
allocator.save('rl_global_equity_model')

print("\n✓ Training completed and model saved!")
# Out:
# ================================================================================
# TRAINING RL GLOBAL EQUITY ALLOCATOR
# ================================================================================
#
# Training Configuration:
#   • Training days: 5457
#   • State dimension: 18
#   • Action dimension: 6
#   • Episodes: 50
#   • Volatility penalty: 0.5
# ---------------------------------------------------------------------------
# InvalidOperationError                     Traceback (most recent call last)
# Cell In[102], line 13
#       2 allocator = RLGlobalEquityAllocator(
#       3     trade_tickers=trade_tickers,
#       4     signal_tickers=signal_tickers,
#    (...)      9     hidden_dim=128
#      10 )
#      12 # Train the agent
# ---> 13 allocator.train(
#      14     model_state=model_state,
#      15     prices=prices,
#      16     num_episodes=50,  # Adjust based on your needs
#      17     update_frequency=2000,
#      18     verbose=True
#      19 )
#      21 # Save trained model
#      22 allocator.save('rl_global_equity_model')
#
# Cell In[101], line 161, in RLGlobalEquityAllocator.train(self, model_state, prices, num_episodes, update_frequency, volatility_window, verbose)
#     158 selected_ticker = self.trade_tickers[action_idx]
#     160 # Get return for selected asset
# --> 161 row_today = prices_df.filter(pl.col("date") == date)
#     162 row_next = prices_df.filter(pl.col("date") == next_date)
#     164 if len(row_today) > 0 and len(row_next) > 0:
#
# File /usr/local/lib/python3.11/site-packages/polars/dataframe/frame.py:5200, in DataFrame.filter(self, *predicates, **constraints)
#    5040 """
#    5041 Filter rows, retaining those that match the given predicate expression(s).
#    5042
#    (...)   5193 └──────┴──────┴─────┘
#    5194 """
#    5195 from polars.lazyframe.opt_flags import QueryOptFlags
#    5197 return (
#    5198     self.lazy()
#    5199     .filter(*predicates, **constraints)
# -> 5200     .collect(optimizations=QueryOptFlags._eager())
#    5201 )
#
# File /usr/local/lib/python3.11/site-packages/polars/_utils/deprecation.py:97, in deprecate_streaming_parameter.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#      93         kwargs["engine"] = "in-memory"
#      95     del kwargs["streaming"]
# ---> 97 return function(*args, **kwargs)
#
# File /usr/local/lib/python3.11/site-packages/polars/lazyframe/opt_flags.py:330, in forward_old_opt_flags.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327         optflags = cb(optflags, kwargs.pop(key))  # type: ignore[no-untyped-call,unused-ignore]
#     329 kwargs["optimizations"] = optflags
# --> 330 return function(*args, **kwargs)
#
# File /usr/local/lib/python3.11/site-packages/polars/lazyframe/frame.py:2335, in LazyFrame.collect(self, type_coercion, predicate_pushdown, projection_pushdown, simplify_expression, slice_pushdown, comm_subplan_elim, comm_subexpr_elim, cluster_with_columns, collapse_joins, no_optimization, engine, background, optimizations, **_kwargs)
#    2333 # Only for testing purposes
#    2334 callback = _kwargs.get("post_opt_callback", callback)
# -> 2335 return wrap_df(ldf.collect(engine, callback))
#
# InvalidOperationError: cannot compare 'date/datetime/time' to a string value (create native python { 'date', 'datetime', 'time' } or compare to a temporal column)

# %% [markdown]
# ## 7. Create Model Registry and Run Backtests

# %%
# Create model registry using the trained allocator
models_registry = {
    "RL_GlobalEquity": {
        "tickers": trade_tickers + signal_tickers,
        "columns": momentum_columns,
        "function": allocator,  # Use the trained allocator instance
    },
}

models = ["RL_GlobalEquity"]

print("✓ Models registry created with RL_GlobalEquity")
# Out:
# ✓ Models registry created with RL_GlobalEquity

# %%
# Run model backtests
model_insights = orchestrate_model_backtests(
    model_state=model_state,
    models=models,
    universe=universe,
    registry=models_registry
)

model_simulations = orchestrate_model_simulations(
    prices=prices,
    model_insights=model_insights
)

print("\nBacktest Results:")
for model_name in models:
    print(f"\n{model_name}:")
    print(model_simulations[model_name]['backtest_metrics'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[55], line 2
#       1 # Run model backtests
# ----> 2 model_insights = orchestrate_model_backtests(
#       3     model_state=model_state,
#       4     models=models,
#       5     universe=universe,
#       6     registry=models_registry
#       7 )
#       9 model_simulations = orchestrate_model_simulations(
#      10     prices=prices,
#      11     model_insights=model_insights
#      12 )
#      14 print("\nBacktest Results:")
#
# File /work/src/trading_engine/core.py:162, in orchestrate_model_backtests(model_state, models, universe, clamp_bounds, registry)
#     159 runner = spec["function"]  # Callable[[LazyFrame], DataFrame|LazyFrame]
#     161 lf_in = _build_model_lazy_input(model_state, tickers=tickers, columns=columns)
# --> 162 out = _ensure_lazy(runner(lf_in))  # ["date", <traded tickers...>]
#     163 out = _coerce_weights_to_float(out)  # float weights
#     164 out = _clamp_weights(out, lo, hi)  # clamp to bounds
#
# Cell In[49], line 276, in RLGlobalEquityAllocator.__call__(self, lf)
#     264 """
#     265 Generate trading weights from model_state.
#     266
#    (...)    273     LazyFrame with columns [date, SPY-US, EWJ-US, ...] containing weights
#     274 """
#     275 if not self.is_trained:
# --> 276     raise ValueError("Model must be trained before generating signals")
#     278 # Collect data
#     279 df = lf.collect()
#
# ValueError: Model must be trained before generating signals

# %% [markdown]
# ## 8. Visualize Results

# %%
# Build equity curves
def build_equity_curve_multi(prices_df, model_simulations, model_names, trade_tickers):
    """Build equity curves for multiple models."""
    prices_collected = prices_df.collect() if hasattr(prices_df, 'collect') else prices_df
    
    curves = {}
    
    for model_name in model_names:
        weights_df = model_simulations[model_name]['backtest_weights']
        if hasattr(weights_df, 'collect'):
            weights_df = weights_df.collect()
        
        # Get portfolio returns
        dates = weights_df.select('date').unique().sort('date')['date'].to_list()
        portfolio_returns = []
        
        for i in range(len(dates) - 1):
            date = dates[i]
            next_date = dates[i + 1]
            
            # Get weights for this date
            weight_row = weights_df.filter(pl.col('date') == date)
            
            # Calculate portfolio return
            portfolio_return = 0.0
            for ticker in trade_tickers:
                if ticker in weight_row.columns:
                    weight = weight_row.select(ticker).to_numpy()[0, 0]
                    
                    # Get price return
                    current_price = prices_collected.filter(
                        (pl.col('date') == date) & (pl.col('ticker') == ticker)
                    ).select('close')
                    next_price = prices_collected.filter(
                        (pl.col('date') == next_date) & (pl.col('ticker') == ticker)
                    ).select('close')
                    
                    if len(current_price) > 0 and len(next_price) > 0:
                        ret = (next_price.to_numpy()[0, 0] - current_price.to_numpy()[0, 0]) / current_price.to_numpy()[0, 0]
                        portfolio_return += weight * ret
            
            portfolio_returns.append(portfolio_return)
        
        # Build equity curve
        equity = [1.0]
        for ret in portfolio_returns:
            equity.append(equity[-1] * (1 + ret))
        
        curves[model_name] = {
            'dates': dates[:len(equity)],
            'equity': equity
        }
    
    return curves


# Build and plot equity curves
equity_curves = build_equity_curve_multi(prices, model_simulations, models, trade_tickers)

plt.figure(figsize=(14, 7))
for model_name in models:
    plt.plot(equity_curves[model_name]['dates'], 
             equity_curves[model_name]['equity'], 
             label=model_name, linewidth=2)

plt.title("RL Global Equity Model vs Baseline", fontsize=14, fontweight='bold')
plt.xlabel("Date")
plt.ylabel("Cumulative Growth of $1")
plt.yscale('log')
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[56], line 58
#      54     return curves
#      57 # Build and plot equity curves
# ---> 58 equity_curves = build_equity_curve_multi(prices, model_simulations, models, trade_tickers)
#      60 plt.figure(figsize=(14, 7))
#      61 for model_name in models:
#
# NameError: name 'model_simulations' is not defined

# %% [markdown]
# ## 9. Analyze Allocation Patterns

# %%
# Analyze how the RL agent allocates across different ETFs
rl_weights = model_simulations['RL_GlobalEquity']['backtest_weights']
if hasattr(rl_weights, 'collect'):
    rl_weights = rl_weights.collect()

# Calculate average allocation to each ETF
print("\nAverage Allocation by RL Agent:")
for ticker in trade_tickers:
    if ticker in rl_weights.columns:
        avg_weight = rl_weights.select(ticker).mean().to_numpy()[0, 0]
        print(f"{ticker:10s}: {avg_weight*100:>6.2f}%")

# Plot allocation over time
fig, ax = plt.subplots(figsize=(14, 7))
dates = rl_weights.select('date')['date'].to_list()

# Create stacked area chart
bottom = np.zeros(len(dates))
for ticker in trade_tickers:
    if ticker in rl_weights.columns:
        weights = rl_weights.select(ticker).to_numpy().flatten()
        ax.fill_between(range(len(dates)), bottom, bottom + weights, label=ticker, alpha=0.7)
        bottom += weights

ax.set_title("RL Agent Allocation Over Time", fontsize=14, fontweight='bold')
ax.set_xlabel("Time")
ax.set_ylabel("Portfolio Weight")
ax.legend(loc='upper left')
ax.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[57], line 2
#       1 # Analyze how the RL agent allocates across different ETFs
# ----> 2 rl_weights = model_simulations['RL_GlobalEquity']['backtest_weights']
#       3 if hasattr(rl_weights, 'collect'):
#       4     rl_weights = rl_weights.collect()
#
# NameError: name 'model_simulations' is not defined

# %% [markdown]
# ## 10. Loading a Pre-trained Model
#
# If you've already trained a model, you can load it for future use:

# %%
# To load a pre-trained model:
# allocator_loaded = RLGlobalEquityAllocator.load('rl_global_equity_model')

# Then use it in your models_registry:
# models_registry = {
#     "RL_GlobalEquity": {
#         "tickers": trade_tickers + signal_tickers,
#         "columns": momentum_columns,
#         "function": allocator_loaded,
#     },
# }

print("Loading example (commented out)")
print("\nTo load and use a pre-trained model:")
print("1. allocator = RLGlobalEquityAllocator.load('rl_global_equity_model')")
print("2. Add it to models_registry")
print("3. Run backtests as normal")
# Out:
# Loading example (commented out)
#
# To load and use a pre-trained model:
# 1. allocator = RLGlobalEquityAllocator.load('rl_global_equity_model')
# 2. Add it to models_registry
# 3. Run backtests as normal
